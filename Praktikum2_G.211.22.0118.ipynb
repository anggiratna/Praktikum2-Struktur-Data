# %% [markdown]
# **TUPLE**

# %%
my_tuple = (11, 15, 43, 56, 72)

# Mengakses elemen berdasarkan indeks
print(my_tuple[0])
print(my_tuple[4])

# Menggunakan slicing untuk mengakses sebagian tuple
print(my_tuple[1:3])
# Out:
# 11
# 72
# (15, 43)

# %% [markdown]
# Menggabungkan Tuple

# %%
tuple1 = (11, 12, 13)
tuple2 = (24, 25, 26)

combined_tuple = tuple1 + tuple2
print(combined_tuple)
# Out:
# (11, 12, 13, 24, 25, 26)

# %% [markdown]
# Mengetahui Panjang Tuple

# %%
my_tuple = (11, 12, 13, 24, 25, 26)
length = len(my_tuple)
print(length)
# Out:
# 6

# %% [markdown]
# Mengetahui Jumlah Kemunculan Elemen dalam Tuple

# %%
my_tuple = (11, 25, 25, 24, 25, 26, 11, 25)
count = my_tuple.count(25)
print(count)
# Out:
# 4

# %% [markdown]
# Mengetahui Indeks Pertama Kemunculan Elemen dalam Tuple

# %%
my_tuple = (11, 25, 25, 24, 25, 26, 11, 25)
index = my_tuple.index(26)
print(index)
# Out:
# 5

# %% [markdown]
# **DICTIONARY**

# %%
person = {
    "Nama": "Anggi Ratna",
    "Umur": "28",
    "No.Tlp": "083154088540",
    "Pekerjaan": "Dokter Hewan"
}

# Mengakses nilai berdasarkan kunci (key)
print(person["Nama"])
print(person["Umur"])
print(person["No.Tlp"])
print(person["Pekerjaan"])
# Out:
# Anggi Ratna
# 28
# 083154088540
# Dokter Hewan

# %% [markdown]
# Menambahkan Elemen Dictionary

# %%
person = {
    "Nama": "Anggi Ratna",
    "Umur": "28",
    "No.Tlp": "083154088540",
    "Pekerjaan": "Dokter Hewan"
}

person["Alamat"] = "Nambuhan RT.03 RW.10 Kec.Purwodadi"

# %%
# Mengakses nilai berdasarkan kunci (key)
print(person["Nama"])
print(person["Umur"])
print(person["No.Tlp"])
print(person["Pekerjaan"])
print(person["Alamat"])
# Out:
# Anggi Ratna
# 28
# 083154088540
# Dokter Hewan
# Nambuhan RT.03 RW.10 Kec.Purwodadi

# %% [markdown]
# Mengubah Nilai Elemen Dictionary

# %%
person["Pekerjaan"] = "Dokter Gigi"

# %%
# Mengakses nilai berdasarkan kunci (key)
print(person["Nama"])
print(person["Umur"])
print(person["No.Tlp"])
print(person["Pekerjaan"])
print(person["Alamat"])
# Out:
# Anggi Ratna
# 28
# 083154088540
# Dokter Gigi
# Nambuhan RT.03 RW.10 Kec.Purwodadi

# %% [markdown]
# Menghapus Elemen Dictionary

# %%
del person["No.Tlp"]
print(person)
# Out:
# {'Nama': 'Anggi Ratna', 'Umur': '28', 'Pekerjaan': 'Dokter Hewan'}
